# %% [markdown]
# This Data is to analyse the frequency of position in a particular year

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
df= pd.read_csv('NBA_player_of_the_week.csv',usecols=['Position','Season short'])
#display(df)
yearArray = dict()
for key,value in df.groupby('Season short'):
    yearArray[key]=value['Position']
for each in list(yearArray.keys()):
    #print(pd.Series(yearArray[each]))
#print(yearArray)
    #print('PDSERIES: ',(pd.Series(yearArray[each])).unique())
    dfPosition = pd.DataFrame((pd.Series(yearArray[each])).unique(),index= (pd.Series(yearArray[each])).unique(),columns=['Positions'])
    dfFreq = pd.DataFrame(pd.value_counts(pd.Series(yearArray[each]))).rename(columns={'Position':'Freq'})
    #display(dfPosition)
    #display(dfFreq)
    dfNew= pd.concat([dfPosition,dfFreq],axis=1,sort=False).sort_values(by=['Freq'],ascending= False).reset_index(drop=True)
    display(dfNew)
    plt.figure(figsize=(16,6))
    sns.barplot(x=dfNew['Positions'],y=dfNew['Freq'],palette = 'ocean')
    plt.xlabel(each,fontsize=18)
    plt.show()
# Out:
#   Positions  Freq
# 0        PG     5
# 1        SF     5
# 2        SG     4
# 3        PF     4
# 4         C     3
# 5         F     1
# 6         G     1
#   Positions  Freq
# 0        SF     9
# 1        PF     5
# 2        SG     4
# 3         C     3
# 4        PG     1
# 5         F     1
#   Positions  Freq
# 0        PG     7
# 1        SF     4
# 2        SG     4
# 3        PF     4
# 4         C     3
# 5        FC     1
#   Positions  Freq
# 0        SG     8
# 1        PF     6
# 2        SF     5
# 3        PG     3
# 4        GF     1
#   Positions  Freq
# 0        SG     7
# 1        PG     5
# 2         C     5
# 3        PF     3
# 4        SF     2
# 5        GF     1
#   Positions  Freq
# 0         C     6
# 1        SG     6
# 2        PF     5
# 3        PG     4
# 4        SF     1
# 5         G     1
#   Positions  Freq
# 0        SG     9
# 1        PG     7
# 2        SF     5
# 3        PF     2
#   Positions  Freq
# 0        PG     5
# 1         C     5
# 2        PF     4
# 3        SF     3
# 4        SG     3
# 5         F     2
# 6        GF     1
#   Positions  Freq
# 0         C    13
# 1        PF     3
# 2         F     2
# 3        SG     2
# 4        PG     1
# 5        GF     1
# 6        SF     1
#   Positions  Freq
# 0         C    14
# 1        SF     3
# 2        SG     2
# 3        PF     2
# 4        PG     1
# 5       F-C     1
#   Positions  Freq
# 0         C     9
# 1        PG     6
# 2        PF     3
# 3        SF     2
# 4        SG     1
# 5         F     1
# 6         G     1
#   Positions  Freq
# 0         C     7
# 1        PF     5
# 2        SF     4
# 3        PG     4
# 4        SG     4
#   Positions  Freq
# 0        SF     6
# 1        PF     6
# 2         C     5
# 3        PG     3
# 4       F-C     1
# 5         G     1
# 6        SG     1
# 7        GF     1
#   Positions  Freq
# 0         C     7
# 1        SG     5
# 2        PF     3
# 3        PG     2
# 4         G     2
# 5        FC     2
# 6        GF     1
# 7        SF     1
#   Positions  Freq
# 0        SF     2
# 1        PG     2
# 2        PF     2
# 3         C     2
# 4         G     2
# 5       F-C     1
# 6        FC     1
# 7         F     1
#   Positions  Freq
# 0         C     6
# 1        PF     4
# 2         G     3
# 3        SF     3
# 4        FC     2
# 5       F-C     2
# 6        SG     1
# 7       G-F     1
# 8        PG     1
#   Positions  Freq
# 0         G     8
# 1        PG     3
# 2        SF     3
# 3        SG     2
# 4         F     2
# 5       F-C     2
# 6        PF     2
# 7         C     1
# 8        FC     1
#    Positions  Freq
# 0         FC    11
# 1          G     7
# 2         PG     5
# 3         PF     5
# 4         SG     5
# 5         SF     3
# 6          C     3
# 7          F     2
# 8         GF     1
# 9        G-F     1
# 10       F-C     1
#   Positions  Freq
# 0         G     9
# 1        SG     9
# 2        FC     7
# 3        SF     6
# 4         F     5
# 5        GF     3
# 6        PF     3
# 7        PG     2
# 8         C     2
# 9       F-C     1
#   Positions  Freq
# 0        PF    10
# 1        SF     7
# 2         C     6
# 3         F     5
# 4        SG     5
# 5         G     5
# 6        FC     3
# 7        PG     2
# 8        GF     2
# 9       G-F     1
#   Positions  Freq
# 0         G    15
# 1        SF     6
# 2         F     6
# 3        GF     5
# 4        SG     4
# 5         C     3
# 6        PF     3
# 7        FC     3
# 8        PG     1
#   Positions  Freq
# 0         G    12
# 1        SG    11
# 2         F     8
# 3        PF     5
# 4        FC     3
# 5         C     3
# 6        SF     2
# 7        PG     2
#   Positions  Freq
# 0        SG    10
# 1         G    10
# 2         F     7
# 3        PF     6
# 4        FC     4
# 5        GF     3
# 6         C     3
# 7        SF     2
# 8        PG     1
#   Positions  Freq
# 0         F     9
# 1         G     7
# 2        SG     6
# 3        GF     6
# 4        PF     5
# 5        PG     4
# 6         C     4
# 7        FC     3
# 8        SF     2
#   Positions  Freq
# 0         G    10
# 1         F     8
# 2        SG     7
# 3        PG     6
# 4        FC     6
# 5         C     5
# 6        PF     4
#   Positions  Freq
# 0        PF     9
# 1         F     9
# 2         C     7
# 3        SG     7
# 4         G     5
# 5        SF     4
# 6        FC     2
# 7        PG     2
# 8        GF     1
#   Positions  Freq
# 0         G     8
# 1         F     7
# 2         C     6
# 3        PG     6
# 4        PF     5
# 5        SG     5
# 6        FC     5
# 7        SF     4
#   Positions  Freq
# 0         F     7
# 1         G     6
# 2        SF     5
# 3         C     4
# 4        PG     4
# 5        SG     3
# 6        FC     2
# 7        PF     1
#   Positions  Freq
# 0         F    11
# 1         G     9
# 2        SG     8
# 3        FC     6
# 4        PF     4
# 5        SF     4
# 6        PG     3
# 7        GF     1
#   Positions  Freq
# 0        FC    10
# 1        PF     7
# 2        SF     6
# 3        PG     5
# 4         G     5
# 5         F     5
# 6        SG     4
# 7         C     2
# 8        GF     2
#   Positions  Freq
# 0         G    15
# 1        PG     7
# 2        FC     5
# 3        SG     4
# 4        PF     4
# 5         F     4
# 6         C     3
# 7        SF     1
# 8        GF     1
#   Positions  Freq
# 0         G    12
# 1         F     9
# 2         C     6
# 3        PG     5
# 4        SF     5
# 5        FC     3
# 6        SG     2
# 7        GF     2
#   Positions  Freq
# 0         G    10
# 1        GF     9
# 2         F     7
# 3        SG     5
# 4         C     5
# 5        PG     4
# 6        PF     2
# 7        FC     1
# 8        SF     1
#   Positions  Freq
# 0         G    14
# 1         C     7
# 2         F     6
# 3        SG     6
# 4        GF     5
# 5        PF     3
# 6        FC     2
# 7        SF     2
# 8        PG     1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display
df= pd.read_csv('NBA_player_of_the_week.csv').head(100)
#display(df)
plt.figure(figsize=(16,6))
sns.stripplot(x=df['Season short'],y=df['Age'],linewidth=1.0)
plt.xlabel('Year',fontsize=18)
plt.ylabel('Ages_Participated_by_an_individual_in_that_year',fontsize=16)
plt.show()
dfAge = pd.DataFrame((df['Age']).unique(),index=(df['Age']).unique(),columns=['Age'])
dfAgeFreq = pd.DataFrame(pd.value_counts(df['Age'])).rename(columns={'Age':'AgeFreq'})
#display(dfAge)
#display(dfAgeFreq)
dfCombined = pd.concat([dfAge,dfAgeFreq],axis=1).sort_values(by=('AgeFreq'),ascending=False).reset_index(drop=True)
#display(dfCombined)
plt.figure(figsize=(16,10))
plt.pie(x=dfCombined['AgeFreq'],labels=dfCombined['Age'],autopct='%.2f')
center_circle = plt.Circle((0,0),0.70,color='black',fc='white', linewidth=1.25)
fig= plt.gcf()
fig.gca().add_artist(center_circle)
plt.legend()
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns
from IPython.display import display
df= pd.read_csv('NBA_player_of_the_week.csv',usecols=['Player','Seasons in league','Season short']).head(200)
dfOld= df.groupby(['Season short'])
dfSeason = df['Season short'].unique()
display(dfSeason)
df= df.groupby(['Season short','Player'])
k= dict()
SeasonList=[]
for each,value in dfOld:
    for elem,newValue in value.groupby('Player'):
        #print(elem)
        #display(pd.DataFrame(newValue))
        #print(pd.Series(value['Seasons in league']))
        summedValue=np.sum([newValue['Seasons in league'].values],axis=1)
        k[elem] = summedValue
    newDataFrame= pd.DataFrame(list(k.values()),list(k.keys()),columns=['Total_Seasons_Played in ' + str(each)]).sort_values(by='Total_Seasons_Played in ' + str(each),ascending=False)[0:1]
    for each in newDataFrame['Total_Seasons_Played in ' + str(each)].values:
        SeasonList.append(each)
print(SeasonList)
plt.figure(figsize=(16,10))
sns.barplot(x=list(dfSeason),y=SeasonList,palette='gist_rainbow')
plt.xlabel('Year',fontsize=18)
plt.ylabel('Maximum_Season_Participated_by_an_individual_in_that_year',fontsize=16)
plt.show()
plt.figure(figsize=(16,6))
plt.pie(x=SeasonList,labels =list(dfSeason),autopct='%.2f')
x=plt.Circle((0,0),0.70,fc='white',color='yellow',linewidth=0.05)
fig= plt.gcf()
fig.gca().add_artist(x)
plt.legend()
plt.axis('equal')
plt.show()
# Out:
# array([1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993], dtype=int64)
# [15, 24, 35, 15, 18, 15, 21, 21, 24]
